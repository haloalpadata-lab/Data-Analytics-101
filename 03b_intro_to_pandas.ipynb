# %% [markdown]
# <a href="https://colab.research.google.com/github/haloalpadata-lab/Data-Analytics-101/blob/main/03b_intro_to_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##**PANDAS - Read Data**

# %% [markdown]
# ###LOAD CSV FILE

# %%
# Importing the Pandas library
import pandas as pd

# Loading the dataset into a DataFrame
df = pd.read_csv('/content/sample_data/california_housing_test.csv')

print(df)
print(' ')
# use to_string() to print the entire DataFrame.
print(df.to_string)

# %%
# Importing the Pandas library
import pandas as pd

# Check the number of maximum returned rows:
print(pd.options.display.max_rows) # 60

#Increase the maximum number of rows to display the entire DataFrame:
pd.options.display.max_rows = 9999
df = pd.read_csv('/content/sample_data/california_housing_test.csv')

print(df)

# %% [markdown]
# ###LOAD JSON FILE

# %%
# Load a Python Dictionary (look like JSON structure) into a DataFrame:
import pandas as pd

data = {
  "Duration":{
    "0":60,
    "1":60,
    "2":60,
    "3":45,
    "4":45,
    "5":60
  },
  "Pulse":{
    "0":110,
    "1":117,
    "2":103,
    "3":109,
    "4":117,
    "5":102
  },
  "Maxpulse":{
    "0":130,
    "1":145,
    "2":135,
    "3":175,
    "4":148,
    "5":127
  },
  "Calories":{
    "0":409,
    "1":479,
    "2":340,
    "3":282,
    "4":406,
    "5":300
  }
}

df = pd.DataFrame(data)

print(df)

# %%
# Importing the Pandas library
import pandas as pd

# Loading the JSON dataset into a DataFrame
df = pd.read_json('/content/sample_data/anscombe.json')

print(df.to_string)

# %%
# Print the first 5 rows of the DataFrame:

# Importing the Pandas library
import pandas as pd

# Loading the dataset into a DataFrame
df = pd.read_csv('/content/sample_data/california_housing_test.csv')

print(df.head())

# %%
# Print the top x rows of the DataFrame:

# Importing the Pandas library
import pandas as pd

# Loading the dataset into a DataFrame
df = pd.read_csv('/content/sample_data/california_housing_test.csv')

print(df.head(10)) # Print the top 10 rows of the DataFrame

# %%
# Print the last 5 rows of the DataFrame:

# Importing the Pandas library
import pandas as pd

# Loading the dataset into a DataFrame
df = pd.read_csv('/content/sample_data/california_housing_test.csv')

print(df.tail())

# %%
# Print information about the data:

# Importing the Pandas library
import pandas as pd

# Loading the dataset into a DataFrame
df = pd.read_csv('/content/sample_data/california_housing_test.csv')

print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB
# None

# %%
# Print  a basic statistical summary

# Importing the Pandas library
import pandas as pd

# Loading the dataset into a DataFrame
df = pd.read_csv('/content/sample_data/california_housing_test.csv')

display(df.describe())
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...
